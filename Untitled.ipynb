# %%
# Imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import requests
from web3 import Web3, WebsocketProvider
from functools import reduce
import operator

# %%
df = pd.DataFrame(np.random.rand(50, 2), columns=['BalanceEth', 'BlocksMined'])
df2 = pd.DataFrame(np.random.rand(50, 2), columns=['BalanceEth', 'BlocksMined'])
df3 = pd.DataFrame(np.random.rand(50, 2), columns=['BalanceEth', 'BlocksMined'])
df4 = pd.DataFrame(np.random.rand(50, 2), columns=['BalanceEth', 'BlocksMined'])
df5 = pd.DataFrame(np.random.rand(50, 2), columns=['BalanceEth', 'BlocksMined'])

# %%
ax = df.plot.scatter(x='BalanceEth', y='BlocksMined', color='Red', label='No');
ax = df2.plot.scatter(x='BalanceEth', y='BlocksMined', color='#191970', label='yes_1.5≤reward<2', ax=ax);
ax = df3.plot.scatter(x='BalanceEth', y='BlocksMined', color='#0d98ba', label='yes_1.5≤reward<2', ax=ax);
ax = df4.plot.scatter(x='BalanceEth', y='BlocksMined', color='#003366', label='yes_1.5≤reward<2', ax=ax);
ax = df5.plot.scatter(x='BalanceEth', y='BlocksMined', color='#ffd700', label='yes_1.5≤reward<2', ax=ax);

ax
